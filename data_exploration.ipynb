# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

import pymysql
pymysql.install_as_MySQLdb()

# %%
# Create Engine and Pass in MySQL Connection
engine = create_engine("mysql://root:June-17-94@localhost/baseball_db")
conn = engine.connect()

# %%
#loading batting file
#file = "baseball data/baseballdatabank-2019.2/core/Batting.csv"
statdf = pd.read_sql("SELECT * FROM batting",conn)

# %%
statdf.head()
# Out:
#     playerID  yearID  stint teamID lgID   G   AB   R   H  2B ...   RBI  SB  \
# 0  abercda01    1871      1    TRO   NA   1    4   0   0   0 ...     0   0
# 1   addybo01    1871      1    RC1   NA  25  118  30  32   6 ...    13   8
# 2  allisar01    1871      1    CL1   NA  29  137  28  40   4 ...    19   3
# 3  allisdo01    1871      1    WS3   NA  27  133  28  44  10 ...    27   1
# 4  ansonca01    1871      1    RC1   NA  25  120  29  39  11 ...    16   6
#
#    CS  BB  SO  IBB  HBP SH SF GIDP
# 0   0   0   0                    0
# 1   1   4   0                    0
# 2   1   2   5                    1
# 3   1   0   2                    0
# 4   2   2   1                    0
#
# [5 rows x 22 columns]

# %%
#cleaning up dataset to only include players with at least 200 ABs
statdf = statdf.dropna()
statdf = statdf.loc[statdf['AB']>=200, :]
statdf.head()
# Out:
#       playerID  yearID  stint teamID lgID   G   AB   R   H  2B ...   RBI  SB  \
# 121  ansonca01    1872      1    PH1   NA  46  217  60  90  10 ...    48   6
# 124  barnero01    1872      1    BS1   NA  45  230  81  99  28 ...    44  12
# 130  bechtge01    1872      1    NY2   NA  51  247  61  74  11 ...    42   9
# 153  cummica01    1872      1    NY2   NA  55  249  37  52   9 ...    26   0
# 154  cuthbne01    1872      1    PH1   NA  47  260  83  88  10 ...    47  14
#
#      CS  BB  SO  IBB  HBP SH SF GIDP
# 121   6  16   3                    2
# 124   2   9   4                    3
# 130   1   7   3                    2
# 153   1   4  14                    2
# 154   4   6  10                    2
#
# [5 rows x 22 columns]

# %%
#organizing dataset by player & year
dfplayer = statdf.groupby(['playerID','yearID']).sum()
dfplayer.head()
# Out:
#                   stint    G   AB    R    H  2B  3B  HR  RBI  SB  CS  BB  SO  \
# playerID  yearID
# aaronha01 1954        1  122  468   58  131  27   6  13   69   2   2  28  39
#           1955        1  153  602  105  189  37   9  27  106   3   1  49  61
#           1956        1  153  609  106  200  34  14  26   92   2   4  37  54
#           1957        1  151  615  118  198  27   6  44  132   1   1  57  58
#           1958        1  153  601  109  196  34   4  30   95   4   1  59  49
#
#                   GIDP
# playerID  yearID
# aaronha01 1954      13
#           1955      20
#           1956      21
#           1957      13
#           1958      21

# %%
#loading player info dataset
#file = "baseball data/baseballdatabank-2019.2/core/People.csv"
persondf = pd.read_sql("SELECT * FROM people",conn)
persondf.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01       1981          12        27          USA         CO
# 1  aaronha01       1934           2         5          USA         AL
# 2  aaronto01       1939           8         5          USA         AL
# 3   aasedo01       1954           9         8          USA         CA
# 4   abadan01       1972           8        25          USA         FL
#
#     birthCity deathYear deathMonth deathDay    ...     nameLast  \
# 0      Denver                                  ...      Aardsma
# 1      Mobile                                  ...        Aaron
# 2      Mobile      1984          8       16    ...        Aaron
# 3      Orange                                  ...         Aase
# 4  Palm Beach                                  ...         Abad
#
#         nameGiven weight height bats throws       debut   finalGame   retroID  \
# ...

# %%
#grabbing birthyear from player info dataset
persondf = persondf[['playerID','birthYear']]
persondf.head()
# Out:
#     playerID  birthYear
# 0  aardsda01       1981
# 1  aaronha01       1934
# 2  aaronto01       1939
# 3   aasedo01       1954
# 4   abadan01       1972

# %%
#checking datatype of playerID column
statdf.playerID
# Out:
# 121      ansonca01
# 124      barnero01
# 130      bechtge01
# 153      cummica01
# 154      cuthbne01
# 158      eggleda01
# 161      fishech01
# 162      fislewe01
# 176      gouldch01
# 177       hallge01
# 181      hatfijo01
# 183      hicksna01
# 185      highadi01
# 200      leonaan01
# 203       mackde01
# 204      malonfe01
# 209      mathebo01
# 211      mcbridi01
# 217      mcgeami01
# 218      mcmuljo01
# 219      mcveyca01
# 223      millsev01
# 233      pearcdi01
# 234       pikeli01
# 236      radcljo01
# 241      rogerfr01
# 242      schafha01
# 248      spaldal01
# 250      startjo01
# 258      treacfr01
#            ...
# 75285    suzukku01
# 75286    swansda01
# 75299    tayloch03
# 75300    taylomi02
# 75307    thameer01
# 75319    torregl01
# 75324    travide01
# 75331    troutmi01
# 75332    trumbma01
# 75343    turneju01
# 75344    turnetr01
# 75346    uptonju01
# 75354    valbulu01
# 75357    valenda01
# 75366    vazquch01
# 75378    villach01
# ...

# %%
#merging dataframes on playerID
maindf = pd.merge(persondf, statdf, on='playerID', how='right')
maindf.head()
# Out:
#     playerID  birthYear  yearID  stint teamID lgID    G   AB    R    H ...   \
# 0  aaronha01     1934.0    1954      1    ML1   NL  122  468   58  131 ...
# 1  aaronha01     1934.0    1955      1    ML1   NL  153  602  105  189 ...
# 2  aaronha01     1934.0    1956      1    ML1   NL  153  609  106  200 ...
# 3  aaronha01     1934.0    1957      1    ML1   NL  151  615  118  198 ...
# 4  aaronha01     1934.0    1958      1    ML1   NL  153  601  109  196 ...
#
#    RBI  SB  CS  BB  SO  IBB  HBP  SH SF GIDP
# 0   69   2   2  28  39         3   6  4   13
# 1  106   3   1  49  61    5    3   7  4   20
# 2   92   2   4  37  54    6    2   5  7   21
# 3  132   1   1  57  58   15    0   0  3   13
# 4   95   4   1  59  49   16    1   0  3   21
#
# [5 rows x 23 columns]

# %%
#fixing datatypes in order to do calculations
maindf['yearID'] = maindf.yearID.astype('float64')
maindf['birthYear'] = maindf.birthYear.astype('float64')
maindf = maindf.astype({'AB' : 'float64','H' : 'float64','2B' : 'float64','3B' : 'float64','HR' : 'float64',})

# %%
#calculating age, batting average, slugging, and isolated power
maindf['age'] = maindf['yearID'] - maindf['birthYear']
maindf['SLG'] = (maindf['H'] + (2*maindf['2B']) + (3*maindf['3B']) + (4*maindf['HR']))/maindf['AB']
maindf['AVG'] = maindf['H'] / maindf['AB']
maindf['ISO'] = maindf['SLG'] - maindf['AVG']
maindf.head()
# Out:
#     playerID  birthYear  yearID  stint teamID lgID    G     AB    R      H  \
# 0  aaronha01     1934.0  1954.0      1    ML1   NL  122  468.0   58  131.0
# 1  aaronha01     1934.0  1955.0      1    ML1   NL  153  602.0  105  189.0
# 2  aaronha01     1934.0  1956.0      1    ML1   NL  153  609.0  106  200.0
# 3  aaronha01     1934.0  1957.0      1    ML1   NL  151  615.0  118  198.0
# 4  aaronha01     1934.0  1958.0      1    ML1   NL  153  601.0  109  196.0
#
#      ...     SO  IBB  HBP  SH  SF  GIDP   age       SLG       AVG       ISO
# 0    ...     39         3   6   4    13  20.0  0.544872  0.279915  0.264957
# 1    ...     61    5    3   7   4    20  21.0  0.661130  0.313953  0.347176
# 2    ...     54    6    2   5   7    21  22.0  0.679803  0.328407  0.351396
# 3    ...     58   15    0   0   3    13  23.0  0.725203  0.321951  0.403252
# 4    ...     49   16    1   0   3    21  24.0  0.658902  0.326123  0.332779
#
# [5 rows x 27 columns]

# %%
#dropping birthyear to be replaced by age
maindf = maindf.drop(columns ='birthYear')
maindf.head()
# Out:
#     playerID  yearID  stint teamID lgID    G     AB    R      H    2B  \
# 0  aaronha01  1954.0      1    ML1   NL  122  468.0   58  131.0  27.0
# 1  aaronha01  1955.0      1    ML1   NL  153  602.0  105  189.0  37.0
# 2  aaronha01  1956.0      1    ML1   NL  153  609.0  106  200.0  34.0
# 3  aaronha01  1957.0      1    ML1   NL  151  615.0  118  198.0  27.0
# 4  aaronha01  1958.0      1    ML1   NL  153  601.0  109  196.0  34.0
#
#      ...     SO  IBB  HBP  SH  SF  GIDP   age       SLG       AVG       ISO
# 0    ...     39         3   6   4    13  20.0  0.544872  0.279915  0.264957
# 1    ...     61    5    3   7   4    20  21.0  0.661130  0.313953  0.347176
# 2    ...     54    6    2   5   7    21  22.0  0.679803  0.328407  0.351396
# 3    ...     58   15    0   0   3    13  23.0  0.725203  0.321951  0.403252
# 4    ...     49   16    1   0   3    21  24.0  0.658902  0.326123  0.332779
#
# [5 rows x 26 columns]

# %%
#saving new dataframe 
maindf.to_sql('player_stats',conn,if_exists='replace')

# %%
#opening fielding data
file = "baseball data/baseballdatabank-2019.2/core/Fielding.csv"
fieldf = pd.read_csv(file)

# %%
fieldf
# Out:
#          playerID  yearID  stint teamID lgID POS    G     GS  InnOuts   PO  \
# 0       abercda01    1871      1    TRO  NaN  SS    1    1.0     24.0    1
# 1        addybo01    1871      1    RC1  NaN  2B   22   22.0    606.0   67
# 2        addybo01    1871      1    RC1  NaN  SS    3    3.0     96.0    8
# 3       allisar01    1871      1    CL1  NaN  2B    2    0.0     18.0    1
# 4       allisar01    1871      1    CL1  NaN  OF   29   29.0    729.0   51
# 5       allisdo01    1871      1    WS3  NaN   C   27   27.0    681.0   68
# 6       ansonca01    1871      1    RC1  NaN  1B    1    0.0     15.0    7
# 7       ansonca01    1871      1    RC1  NaN  2B    2    1.0     30.0    3
# 8       ansonca01    1871      1    RC1  NaN  3B   20   19.0    555.0   38
# 9       ansonca01    1871      1    RC1  NaN   C    5    4.0     93.0   10
# 10      ansonca01    1871      1    RC1  NaN  OF    1    1.0      6.0    0
# ...
